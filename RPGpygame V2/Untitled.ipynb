# %%
from random import randint

class Enemy():
    def __init__(self,name=None):
        self.name=name
        
class Thug(Enemy):
    maxHealth=50
    curHealth=maxHealth
  
class Bandit(Enemy):
    maxHealth=60
    curHealth=maxHealth
    
class Pit_Fighter(Enemy):
    maxHealth=70
    curHealth=maxHealth
        
class Guard(Enemy):
    maxHealth=80
    curHealth=maxHealth
    
def Combat(combNum,emem1type,enemNam1=None,emem2type=None,enemNam2=None,emem3type=None,enemNam3=None,emem4type=None,enemNam4=None,emem5type=None,enemNam5=None):
#
    if emem1type == "Thug":
        enem1=Thug(enemNam1)
    elif emem1type == "Bandit":
        enem1=Bandit(enemNam1)
    elif emem1type == "Pit_Fighter":
        enem1=Pit_Fighter(enemNam1)
    # 
    if enem1.name==None: 
        enem1.name=emem1type
#
    if combNum>1:
        if emem2type == "Thug":
            enem2=Thug()
        elif emem2type == "Bandit":
            enem2=Bandit()
        elif emem2type == "Pit_Fighter":
            enem2=Bandit() 
        enem2.name=emem2type 
        # 
        if enem2.name==None: 
            enem2.name=emem2type  
#
    if combNum>2:
        if emem3type == "Thug":
            enem3=Thug()
        elif emem3type == "Bandit":
            enem3=Bandit()
        elif emem3type == "Pit_Fighter":
            enem3=Pit_Fighter() 
        enem3.name=emem3type 
        # 
        if enem3.name==None: 
            enem3.name=emem3type
#
    if combNum>3:
        if emem4type == "Thug":
            enem4=Thug()
        elif emem4type == "Bandit":
            enem4=Bandit()
        elif emem4type == "Pit_Fighter":
            enem4=Pit_Fighter() 
        enem4.name=emem4type 
        # 
        if enem4.name==None: 
            enem4.name=emem4type
#
    if combNum>4:
        if emem5type == "Thug":
            enem5=Thug()
        elif emem5type == "Bandit":
            enem5=Bandit()
        elif emem5type == "Pit_Fighter":
            enem5=Pit_Fighter() 
        enem5.name=emem5type 
        # 
        if enem5.name==None: 
            enem5.name=emem5type
#
    while True:# player's turn
        try:
            print('Enemy: {} - Health: {}/{}'.format(enem1.name,enem1.curHealth,enem1.maxHealth))
            if combNum>1:
                print('Enemy: {} - Health: {}/{}'.format(enem2.name,enem2.curHealth,enem2.maxHealth))
                if combNum>2:
                    print('Enemy: {} - Health: {}/{}'.format(enem3.name,enem3.curHealth,enem3.maxHealth))
                    if combNum>3:
                        print('Enemy: {} - Health: {}/{}'.format(enem3.name,enem3.curHealth,enem3.maxHealth))
                        if combNum>4:
                            print('Enemy: {} - Health: {}/{}'.format(enem3.name,enem3.curHealth,enem3.maxHealth))
            
            izbor=int(input("1 - Attack\n2 - Defend\n3 - use Ability\n4 - Use item\n5 - Do Nothing\n6- Surrender\n"))
            if izbor == 1:
                print("choose an enemy")
                print('1 Enemy: {} - Health: {}/{}'.format(enem1.name,enem1.curHealth,enem1.maxHealth))
                if combNum>1:
                    print('2 Enemy: {} - Health: {}/{}'.format(enem2.name,enem2.curHealth,enem2.maxHealth))
                    if combNum>2:
                        print('3 Enemy: {} - Health: {}/{}'.format(enem3.name,enem3.curHealth,enem3.maxHealth))
                        if combNum>3:
                            print('4 Enemy: {} - Health: {}/{}'.format(enem3.name,enem3.curHealth,enem3.maxHealth))
                            if combNum>4:
                                print('5 Enemy: {} - Health: {}/{}'.format(enem3.name,enem3.curHealth,enem3.maxHealth))  
                izbor_Atk=int(input("6. Back"))
                if izbor_Atk==1:
                    enem1.curHealth-=20
                if izbor_Atk==6:
                    pass
            elif izbor == 2:
                pass
            elif izbor == 3:
                pass
            elif izbor == 4:
                pass
            elif izbor == 5:
                pass
            #break
        except ValueError:
            print("Invalid Input")
        
#Combat(5,"Thug",emem2type="Bandit",emem3type="Pit_Fighter",emem4type="Pit_Fighter",emem5type="Pit_Fighter")
Combat(2,"Thug",enemNam1="george",emem2type="Bandit")
